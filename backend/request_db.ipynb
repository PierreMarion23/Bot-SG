# %% [markdown]
# # Corporate Actions DB
# ### Extract and Data Preparation
# + Repo: https://sgithub.fr.world.socgen/oborderi/bot-ca

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import display

from corp_actions.db_analysis.db import DB

# %%
db = DB()

# %%
# %%time
# db.get_from_api_all()

# %%
# db.put_to_disk()

# %%
db.get_from_disk()
# Out:
# read tables from disk
# 	table convertible_bond
# 	table right_issue
# 	table merger_acquisition
# 	table spin_off
# 	table buy_back
# 	table optional_dividend

# %%
db.get_bbg_data()
# Out:
# bbg\df_bbg_mktcap.csv loaded
# bbg\df_bbg_sector.csv loaded
# bbg\df_bbg_exchange.csv loaded

# %%
db.build_share()
# Out:
# extract shares from tables - build df_share
# 	convertible_bond	234
# 	right_issue	941
# 	merger_acquisition	1227
# 	optional_dividend	3040
# 	buy_back	3074
# 	spin_off	3091
# nb shares = 3091
# nb unique shares = 1158

# %%
db.filter_all()
# Out:
# shape convertible_bond
# 	invalid status:['CANCELLED', 'DENIED', 'POSSIBLE']
# 	regular 	caKey
# 	regular 	status
# 	regular 	amountIssued
# 	specific	*cbCurrency
# 	specific	*cbCoupon
# 	regular 	issueDate
# 	regular 	ratchetClause
# 	regular 	share
# 	specific phase
# 		cbCurrency
# 		cbCoupon
# 	convert dates to datetime
# 		issueDate
# shape right_issue
# 	invalid status:['CANCELLED', 'DENIED', 'POSSIBLE']
# 	regular 	caKey
# 	regular 	status
# 	regular 	subscriptionPriceCurrency
# 	regular 	amountToBeRaised
# 	regular 	terms
# 	regular 	exDate
# 	specific	*transferable
# 	regular 	oversubscriptionType
# 	specific	*primaryAllocationMethod
# 	specific	*secondaryAllocationMethod
# 	specific	*tertiaryAllocationMethod
# 	regular 	discountToTerpProspectusPublicationDate
# 	regular 	primarySubscriptionRatio
# 	regular 	secondarySubscriptionRatio
# 	regular 	tertiarySubscriptionRatio
# 	regular 	share
# 	specific phase
# 		transferable
# 		primaryAllocationMethod
# 		secondaryAllocationMethod
# 		tertiaryAllocationMethod
# 	convert dates to datetime
# 		exDate
# 		discountToTerpProspectusPublicationDate
# shape merger_acquisition
# 	invalid status:['CANCELLED', 'DENIED', 'POSSIBLE']
# 	regular 	caKey
# 	regular 	type
# 	regular 	status
# 	regular 	takeOverType
# 	regular 	maxCashTakeUp
# 	regular 	maxSharesTakeUp
# 	regular 	paymentType
# 	regular 	share
# 	specific phase
# 	convert dates to datetime
# shape optional_dividend
# 	invalid status:['CANCELLED', 'DENIED', 'POSSIBLE']
# 	regular 	caKey
# 	regular 	status
# 	regular 	exDate
# 	regular 	hasCashStockOption
# 	regular 	optionType
# 	regular 	reinvestmentPxCalcDuration
# 	regular 	reinvestmentPxCalcDiscount
# 	regular 	reinvestmentRatio
# 	specific	*transferable
# 	specific	*tradable
# 	specific	*listedOnExchange
# 	regular 	hasFxOption
# 	regular 	share
# 	specific phase
# 		transferable
# 		tradable
# 		listedOnExchange
# 	convert dates to datetime
# 		exDate
# shape buy_back
# 	invalid status:['CANCELLED', 'DENIED', 'POSSIBLE']
# 	regular 	caKey
# 	regular 	type
# 	regular 	status
# 	regular 	percentSought
# 	regular 	buybackType
# 	regular 	toAuctionProratationMethod
# 	regular 	paymentType
# 	regular 	buybackTaxed
# 	regular 	lastTenderDate
# 	regular 	serviceRatio
# 	regular 	share
# 	specific phase
# 	convert dates to datetime
# 		lastTenderDate
# shape spin_off
# 	invalid status:['CANCELLED', 'DENIED', 'POSSIBLE']
# 	regular 	caKey
# 	regular 	status
# 	regular 	spinOffCompanyListedBeforeSpinOff
# 	regular 	exDate
# 	regular 	share
# 	specific phase
# 	convert dates to datetime
# 		exDate

# %%
db.put_to_csv()
# Out:
# save dataframes to disk
# 	convertible_bond         	dump\df_convertible_bond.csv
# 	right_issue              	dump\df_right_issue.csv
# 	merger_acquisition       	dump\df_merger_acquisition.csv
# 	optional_dividend        	dump\df_optional_dividend.csv
# 	buy_back                 	dump\df_buy_back.csv
# 	spin_off                 	dump\df_spin_off.csv
# 	share                    	dump\df_share.csv

# %%
db.overview()
# Out:
# Overview - dataframes structures
#
# convertible_bond
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 0 to 233
# Data columns (total 8 columns):
# caKey            234 non-null object
# status           234 non-null object
# amountIssued     233 non-null float64
# issueDate        227 non-null datetime64[ns]
# ratchetClause    0 non-null object
# share            234 non-null object
# cbCurrency       233 non-null object
# cbCoupon         226 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 16.5+ KB
#
# right_issue
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679 entries, 1 to 706
# Data columns (total 16 columns):
# caKey                                      679 non-null object
# status                                     679 non-null object
# subscriptionPriceCurrency                  674 non-null object
# amountToBeRaised                           527 non-null float64
# terms                                      665 non-null float64
# exDate                                     670 non-null datetime64[ns]
# oversubscriptionType                       677 non-null object
# discountToTerpProspectusPublicationDate    0 non-null datetime64[ns]
# primarySubscriptionRatio                   455 non-null float64
# secondarySubscriptionRatio                 454 non-null float64
# tertiarySubscriptionRatio                  436 non-null float64
# share                                      679 non-null object
# transferable                               356 non-null object
# primaryAllocationMethod                    679 non-null object
# secondaryAllocationMethod                  679 non-null object
# tertiaryAllocationMethod                   679 non-null object
# dtypes: datetime64[ns](2), float64(5), object(9)
# memory usage: 90.2+ KB
#
# merger_acquisition
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132 entries, 0 to 142
# Data columns (total 8 columns):
# caKey              132 non-null object
# type               132 non-null object
# status             132 non-null object
# takeOverType       130 non-null object
# maxCashTakeUp      0 non-null object
# maxSharesTakeUp    0 non-null object
# paymentType        129 non-null object
# share              132 non-null object
# dtypes: object(8)
# memory usage: 9.3+ KB
#
# optional_dividend
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1780 entries, 0 to 1812
# Data columns (total 13 columns):
# caKey                         1780 non-null object
# status                        1780 non-null object
# exDate                        1755 non-null datetime64[ns]
# hasCashStockOption            1779 non-null object
# optionType                    1780 non-null object
# reinvestmentPxCalcDuration    1758 non-null float64
# reinvestmentPxCalcDiscount    1386 non-null float64
# reinvestmentRatio             1062 non-null float64
# hasFxOption                   1779 non-null object
# share                         1780 non-null object
# transferable                  1513 non-null object
# tradable                      1733 non-null object
# listedOnExchange              1513 non-null object
# dtypes: datetime64[ns](1), float64(3), object(9)
# memory usage: 194.7+ KB
#
# buy_back
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 33
# Data columns (total 11 columns):
# caKey                         33 non-null object
# type                          33 non-null object
# status                        33 non-null object
# percentSought                 23 non-null float64
# buybackType                   31 non-null object
# toAuctionProratationMethod    9 non-null object
# paymentType                   29 non-null object
# buybackTaxed                  11 non-null object
# lastTenderDate                23 non-null datetime64[ns]
# serviceRatio                  9 non-null float64
# share                         33 non-null object
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 3.1+ KB
#
# spin_off
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 5 columns):
# caKey                                17 non-null object
# status                               17 non-null object
# spinOffCompanyListedBeforeSpinOff    6 non-null object
# exDate                               16 non-null datetime64[ns]
# share                                17 non-null object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 816.0+ bytes
#
# share
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158 entries, 0 to 1157
# Data columns (total 29 columns):
# arbitrageSellingAllowed     574 non-null object
# bloombergCode               1158 non-null object
# bloombergTickerCode         960 non-null object
# countryOfIncorporation      960 non-null object
# countryOfRegistration       659 non-null object
# creationTs                  1158 non-null datetime64[ns]
# currency                    1150 non-null object
# eliotCode                   932 non-null object
# galaxyCode                  961 non-null object
# isActive                    961 non-null object
# isCent                      961 non-null object
# isinCode                    962 non-null object
# issuedSecuritiesNumber      385 non-null float64
# issuedShareTemporary        352 non-null object
# issuerName                  961 non-null object
# longName                    961 non-null object
# mainInstrumentGalaxyCode    961 non-null object
# marketCapitalization        34 non-null float64
# masterShare                 961 non-null object
# multipleShare               961 non-null object
# ricCode                     954 non-null object
# rtFloorFeedCode             960 non-null object
# rtFloorFeedCurrency         938 non-null object
# rtFloorFeedSource           938 non-null object
# rtOrderPassingCode          960 non-null object
# shareOutStanding            997 non-null float64
# shortSellingAllowed         574 non-null object
# type                        1158 non-null object
# updateTs                    991 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), object(24)
# memory usage: 262.4+ KB

# %%
db.distinct_values()
# Out:
# convertible_bond
# 	 number columns: ['amountIssued', 'cbCoupon']
# 	 date columns: ['issueDate']
# right_issue
# 	 number columns: ['amountToBeRaised', 'terms', 'primarySubscriptionRatio', 'secondarySubscriptionRatio', 'tertiarySubscriptionRatio']
# 	 date columns: ['exDate', 'discountToTerpProspectusPublicationDate']
# merger_acquisition
# 	 number columns: []
# 	 date columns: []
# optional_dividend
# 	 number columns: ['reinvestmentPxCalcDuration', 'reinvestmentPxCalcDiscount', 'reinvestmentRatio']
# 	 date columns: ['exDate']
# buy_back
# 	 number columns: ['percentSought', 'serviceRatio']
# 	 date columns: ['lastTenderDate']
# spin_off
# 	 number columns: []
# 	 date columns: ['exDate']
#
# Overview - distinct values
# {
#   "convertible_bond": {
#     "ratchetClause": [
#       null
#     ],
#     "amountIssued": {
#       "avg": 496242335.1188841,
#       "max": 4000000000.0,
#       "type": "number",
#       "min": 65000000.0
#     },
#     "cbCoupon": {
#       "avg": 3.030292256637168,
#       "max": 9.0,
#       "type": "number",
#       "min": 0.0
#     },
#     "issueDate": {
#       "latest": "2017-09-01",
#       "type": "date",
#       "earliest": "2000-02-17"
#     },
#     "status": [
#       "CONFIRMED",
#       "UNDEFINED"
#     ],
#     "cbCurrency": [
#       "USD",
#       null,
#       "SGD",
#       "GBP",
#       "SEK",
#       "EUR",
#       "CHF"
#     ]
#   },
#   "right_issue": {
#     "oversubscriptionType": [
#       "UNKNOWN",
#       null,
#       "PROPORTIONAL_SHARES_REQUESTED",
#       "PROPORTIONAL_SHARES_HELD",
#       "PROPORTIONAL_ADVANCED_CASH",
#       "PROPORTIONAL_RIGHTS_EXERCISED",
#       "NONE"
#     ],
#     "exDate": {
#       "latest": "2018-01-08",
#       "type": "date",
#       "earliest": "2007-01-04"
#     },
#     "secondarySubscriptionRatio": {
#       "avg": 0.11950484161442974,
#       "max": 8.308916074,
#       "type": "number",
#       "min": 0.0
#     },
#     "status": [
#       "EXPECTED",
#       "CONFIRMED",
#       "DONE",
#       "WATCH_LIST"
#     ],
#     "discountToTerpProspectusPublicationDate": {
#       "latest": null,
#       "type": "date",
#       "earliest": null
#     },
#     "amountToBeRaised": {
#       "avg": 937139175.172892,
#       "max": 21998046861.0,
#       "type": "number",
#       "min": 0.0
#     },
#     "tertiarySubscriptionRatio": {
#       "avg": 0.0037635063004538625,
#       "max": 0.747784367,
#       "type": "number",
#       "min": 0.0
#     },
#     "terms": {
#       "avg": 2.884210245836228,
#       "max": 397.0,
#       "type": "number",
#       "min": -1.0
#     },
#     "tertiaryAllocationMethod": [
#       "PRIVATE_PLACEMENT",
#       "UNDERWRITER",
#       "UNKNOWN"
#     ],
#     "subscriptionPriceCurrency": [
#       "GBp",
#       null,
#       "USD",
#       "PLN",
#       "NOK",
#       "GBP",
#       "SEK",
#       "DKK",
#       "AUD",
#       "ZAR",
#       "EUR",
#       "CHF"
#     ],
#     "primarySubscriptionRatio": {
#       "avg": 0.24476511392559308,
#       "max": 1.0,
#       "type": "number",
#       "min": 0.0
#     },
#     "transferable": [
#       false,
#       true,
#       null
#     ],
#     "primaryAllocationMethod": [
#       "UNKNOWN",
#       "OVER_SUBSCRIPTION",
#       "SOLD_ON_OPEN_MARKET",
#       "PREFERENTIAL_SUBSCRIPTION_RIGHTS",
#       "AUCTION",
#       "PRIVATE_PLACEMENT"
#     ],
#     "secondaryAllocationMethod": [
#       "UNKNOWN",
#       "OVER_SUBSCRIPTION",
#       "SOLD_ON_OPEN_MARKET",
#       "PREFERENTIAL_SUBSCRIPTION_RIGHTS",
#       "AUCTION",
#       "PRIVATE_PLACEMENT",
#       "UNDERWRITER"
#     ]
#   },
#   "merger_acquisition": {
#     "type": [
#       "MERGER_ACQUISITION"
#     ],
#     "status": [
#       "EXPECTED",
#       "WATCH_LIST",
#       "CONFIRMED",
#       "RUMOR"
#     ],
#     "paymentType": [
#       "CASH",
#       "STOCK",
#       null,
#       "CASH_OR_STOCK",
#       "CASH_AND_STOCK"
#     ],
#     "maxCashTakeUp": [
#       null
#     ],
#     "takeOverType": [
#       "UNKNOWN",
#       "FRIENDLY",
#       null
#     ],
#     "maxSharesTakeUp": [
#       null
#     ]
#   },
#   "spin_off": {
#     "status": [
#       "CONFIRMED",
#       "WATCH_LIST",
#       "UNDEFINED"
#     ],
#     "exDate": {
#       "latest": "2016-09-12",
#       "type": "date",
#       "earliest": "2010-07-02"
#     },
#     "spinOffCompanyListedBeforeSpinOff": [
#       false,
#       null
#     ]
#   },
#   "buy_back": {
#     "buybackType": [
#       "TENDER_OFFER",
#       null,
#       "DUTCH_AUCTION"
#     ],
#     "toAuctionProratationMethod": [
#       null,
#       "Pro rata tendered",
#       "prorata tendered",
#       "Pro rata shares tendered",
#       "Pro rata shares held",
#       "3 per 31",
#       "25% Linear + 75% pro rata"
#     ],
#     "type": [
#       "BUY_BACK"
#     ],
#     "buybackTaxed": [
#       false,
#       true,
#       null
#     ],
#     "lastTenderDate": {
#       "latest": "2017-11-30",
#       "type": "date",
#       "earliest": "2011-10-03"
#     },
#     "status": [
#       "WATCH_LIST",
#       "CONFIRMED"
#     ],
#     "paymentType": [
#       "CASH",
#       null
#     ],
#     "percentSought": {
#       "avg": 0.11328607737989245,
#       "max": 0.36,
#       "type": "number",
#       "min": 0.0
#     },
#     "serviceRatio": {
#       "avg": 0.14603333333333335,
#       "max": 1.0,
#       "type": "number",
#       "min": 0.0
#     }
#   },
#   "optional_dividend": {
#     "reinvestmentPxCalcDuration": {
#       "avg": 6.080204778156997,
#       "max": 60.0,
#       "type": "number",
#       "min": 0.0
#     },
#     "reinvestmentPxCalcDiscount": {
#       "avg": 0.020319849927850013,
#       "max": 0.2,
#       "type": "number",
#       "min": -1.0
#     },
#     "reinvestmentRatio": {
#       "avg": 6.209851514175285,
#       "max": 811.4,
#       "type": "number",
#       "min": 0.0
#     },
#     "tradable": [
#       false,
#       true,
#       null
#     ],
#     "hasCashStockOption": [
#       false,
#       true,
#       null
#     ],
#     "status": [
#       "EXPECTED",
#       "WATCH_LIST",
#       "CONFIRMED"
#     ],
#     "listedOnExchange": [
#       false,
#       true,
#       null
#     ],
#     "hasFxOption": [
#       false,
#       true,
#       null
#     ],
#     "exDate": {
#       "latest": "2018-06-05",
#       "type": "date",
#       "earliest": "2008-05-28"
#     },
#     "optionType": [
#       "SCRIP",
#       "STOCK_ONLY",
#       "DRIP",
#       "NONE"
#     ],
#     "transferable": [
#       false,
#       true,
#       null
#     ]
#   }
# }
